# %%
import pandas as pd
import os 
from pathlib import Path

# %%
df = pd.read_parquet("data/natural_counterfactuals/heart_disease_counterfactual_dataset_balanced.parquet")

# %%
# some stats

print(f"{len(df.columns)=}")
print(f"{len(df)=}")
print(df.iloc[0])
# Out:
# len(df.columns)=33
# len(df)=3022
# original_dataset                                                                                 heart_disease
# original_question                                            This is a male patient, experiencing asymptoma...
# original_question_prompt                                     You are a medical diagnosis assistant. Based o...
# original_question_idx                                                                                        1
# original_ground_truth                                                                                      YES
# original_answer_first                                                                                     True
# original_description                                         This is a male patient, experiencing asymptoma...
# original_question_options                                                                                 None
# ...

# %%
# How to check whether outut dir is valid

output_dir = "/experiments"

project = Path("/Users/Elliot/Documents/bluedot-faithfulness-project")
target = project / "experiments"

if target.exists():
    print("dir exists")
# Out:
# dir exists
