# %%
import pandas as pd
import numpy as np

# %%
# %cd ../data/natural_counterfactuals
# %pwd
# Out:
# /Users/elliot/Documents/bluedot-faithfulness-project/data/natural_counterfactuals
# '/Users/elliot/Documents/bluedot-faithfulness-project/data/natural_counterfactuals'

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_parquet('heart_disease_counterfactual_dataset_balanced.parquet')
df.iloc[0:50]
# Out:
#    original_dataset                                  original_question  \
# 0     heart_disease  This is a male patient, experiencing asymptoma...
# 1     heart_disease  This is a male patient, experiencing asymptoma...
# 2     heart_disease  This is a male patient, experiencing asymptoma...
# 3     heart_disease  This is a male patient, experiencing asymptoma...
# 4     heart_disease  This is a male patient, experiencing asymptoma...
# 5     heart_disease  This is a male patient, experiencing asymptoma...
# 6     heart_disease  This is a male patient, experiencing asymptoma...
# 7     heart_disease  This is a male patient, experiencing asymptoma...
# 8     heart_disease  This is a male patient, experiencing asymptoma...
# 9     heart_disease  This is a male patient, experiencing asymptoma...
# 10    heart_disease  This is a male patient, experiencing asymptoma...
# 11    heart_disease  This is a male patient, experiencing asymptoma...
# ...
