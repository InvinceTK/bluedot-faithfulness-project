# %%
import pandas as pd

# %%
df = pd.read_parquet("../data/natural_counterfactuals/heart_disease_counterfactual_dataset_balanced.parquet")

df_1 = df.iloc[[0]]   # double brackets → keeps it a DataFrame, one row, columns intact

path = "../data/natural_counterfactuals/1_heart_disease_counterfactual_dataset_balanced.parquet"
df_1.to_parquet(path)
