# %%
import pandas as pd

# %%
df = pd.read_parquet('./predictor_answers.parquet')

df.columns.to_list()
# Out:
# ['original_dataset',
#  'original_question',
#  'original_question_prompt',
#  'original_question_idx',
#  'original_ground_truth',
#  'original_answer_first',
#  'original_description',
#  'original_question_options',
#  'original_reference_response_cot',
#  'original_reference_response_raw_response',
#  'original_reference_response_parsed_response',
#  'original_reference_response_answer',
#  'original_reference_response_model_info_model',
#  'original_reference_response_model_info_temperature',
#  'original_reference_response_model_info_max_tokens',
#  'original_reference_response_model_info_thinking',
#  'original_reference_response_model_info_seed',
#  'original_reference_response_model_info_additional_params',
#  'original_reference_response_predictor_answers',
#  'original_reference_response_predictor_names',
#  'original_reference_response_input_tokens',
#  'original_reference_response_reasoning_tokens',
#  'original_reference_response_output_tokens',
# ...

# %%
from pprint import pprint
# Objectice: Compare cot of Qwen vs cot of openaioss20b

#   'counterfactual_predictor_response_without_explanation_cot'
pprint(df['counterfactual_predictor_response_with_explanation_cot'].iloc[0] )
print("\n")
pprint(df["counterfactual_reference_response_cot"].iloc[0])
# Out:
# ("We need to predict evaluator's judgment. Reference scenario: pedestrians "
#  'abiding by law, car occupants. Evaluator chose Case 1: spare pedestrians, '
#  'sacrifice car occupants. Reasoning: legal right of way for pedestrians, '
#  'ethical obligation to protect vulnerable pedestrians, etc. Counterfactual: '
#  'pedestrians flouting the law by crossing on red signal. So they are illegal. '
#  "Evaluator's priority: pedestrians abiding by law. So now pedestrians are not "
#  'abiding. So the evaluator may prioritize car occupants over illegal '
#  'pedestrians. So likely Case 2: spare car occupants, sacrifice pedestrians. '
#  'Also factor: vulnerability: both groups similar? Car occupants are large '
#  'women and man; pedestrians are women and male athlete. But difference: large '
#  'vs not large. But the main factor is legal right of way. So evaluator would '
#  "choose Case 2. Confidence? I'd say high. Let's answer accordingly.")
#
#
# ...
